# %%
import json

filename = "random0.3_chat.json"

# Load the JSON file containing chat abstracts
with open(filename, "r", encoding="utf-8") as f:
    chat_dict = json.load(f)

# Prepare a list of chat abstracts with "gen" label
chat_abstracts = []
for edge_key, entry in chat_dict.items():
    out_text = entry.get("out", "").strip()
    if out_text:
        chat_abstracts.append(("gen", out_text))

# %%
from Bio import Entrez
import time

# Set your email (required by NCBI)
Entrez.email = "zilinfg@gmail.com"  # Replace with your email

def get_pmids(query, count=100):
    """Fetch up to `count` PubMed IDs for a given search query."""
    handle = Entrez.esearch(db="pubmed", term=query, retmax=count)
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

def fetch_abstracts(pmids):
    """Given a list of PMIDs, returns a dict { pmid: abstract_text }."""
    abstracts = {}
    batch_size = 100

    for i in range(0, len(pmids), batch_size):
        chunk = pmids[i: i + batch_size]
        ids_str = ",".join(chunk)

        handle = Entrez.efetch(db="pubmed", id=ids_str, retmode="xml")
        records = Entrez.read(handle)
        handle.close()

        for article in records.get("PubmedArticle", []):
            pmid_elem = article["MedlineCitation"]["PMID"]
            pmid = str(pmid_elem)

            abstract_text = ""
            art = article["MedlineCitation"]["Article"]
            if art.get("Abstract") and art["Abstract"].get("AbstractText"):
                parts = art["Abstract"]["AbstractText"]
                if isinstance(parts, list):
                    collected = []
                    for chunk in parts:
                        if isinstance(chunk, str):
                            collected.append(chunk)
                        elif isinstance(chunk, dict):
                            collected.append(chunk.get("#text", ""))
                    abstract_text = " ".join(collected)
                elif isinstance(parts, str):
                    abstract_text = parts

            abstracts[pmid] = abstract_text
        time.sleep(0.4)

    # Ensure all requested PMIDs have an entry (even if no abstract was found)
    for pmid in pmids:
        abstracts.setdefault(pmid, "")

    return abstracts

# --- USAGE ---
query = "cancer"  # Change this to any search topic of interest
pmids = get_pmids(query, count=100)
pubmed_abstracts = fetch_abstracts(pmids)

# Prepare a list of PubMed abstracts with "real" label
pubmed_abstracts = [("real", abstract) for pmid, abstract in pubmed_abstracts.items()]

# %%
import random

# Combine both sets of abstracts
combined_abstracts = chat_abstracts + pubmed_abstracts

# Shuffle the combined abstracts
random.shuffle(combined_abstracts)

print(len(chat_abstracts))
# Out:
# 124

# %%
import random
import google.generativeai as genai

def ask_gemini_which_is_more_factual(abstract_text_1, abstract_text_2, gemini_model):
    """
    Sends two abstracts to the Gemini API and returns the number (1 or 2)
    of the abstract deemed more factual.

    Args:
        abstract_text_1 (str): The text of the first abstract.
        abstract_text_2 (str): The text of the second abstract.
        gemini_model: Your initialized Gemini model instance.

    Returns:
        int: 1 if Abstract 1 is chosen, 2 if Abstract 2 is chosen.
             Returns None or raises an error on failure/ambiguous response.
    """
    prompt = f"""You will be presented with two abstracts, labeled 'Abstract 1' and 'Abstract 2'. Your task is to determine which of these two abstracts is more likely to be a factual, scientifically accurate abstract originating from a genuine biomedical research publication.

Please respond with only 'Abstract 1' or 'Abstract 2' to indicate your choice. Do not provide any explanation or additional text.

Abstract 1:
{abstract_text_1}

Abstract 2:
{abstract_text_2}
"""
    # --- Make the actual API call ---
    response = gemini_model.generate_content(prompt)

    if "Abstract 1" in response.text and "Abstract 2" not in response.text:
        return 1
    elif "Abstract 2" in response.text and "Abstract 1" not in response.text:
        return 2
    else:
        print(f"Warning: Ambiguous Gemini response: {response.text}")
        return None # Or handle as an error, or random choice for simulation

    # --- SIMULATION / MOCK RESPONSE (Remove for real use) ---
    # print(f"Simulating Gemini call for:\nAbstract 1: {abstract_text_1[:60]}...\nAbstract 2: {abstract_text_2[:60]}...")
    # chosen = random.choice([1, 2])
    # print(f"Gemini (mock) chose: Abstract {chosen}")
    # return chosen
    # --- END SIMULATION ---


# --- Tournament Setup ---
num_abstracts = len(combined_abstracts)
indices = list(range(num_abstracts))
wins = {i: 0 for i in indices}
comparisons_made = {i: 0 for i in indices} 

K_comparisons_per_abstract = 5 

# Initialize your Gemini Model here (outside the loop)
genai.configure(api_key="AIzaSyBikvlkj7sCaiyGV9qhfSXZt54uQM9Gsec")
gemini_llm_model = genai.GenerativeModel('gemini-1.5-flash')


print(f"Starting tournament. Total abstracts: {num_abstracts}. Rounds (K): {K_comparisons_per_abstract}")

for round_num in range(K_comparisons_per_abstract):
    print(f"\n--- Tournament Round {round_num + 1} of {K_comparisons_per_abstract} ---")
    shuffled_indices = list(indices) # Work with a copy
    random.shuffle(shuffled_indices)

    for i in range(0, num_abstracts, 2):
        if i + 1 < num_abstracts:
            idx1 = shuffled_indices[i]
            idx2 = shuffled_indices[i+1]

            original_label1, text1 = combined_abstracts[idx1]
            original_label2, text2 = combined_abstracts[idx2]

            print(f"Comparing pair: Index {idx1} (Label: {original_label1}) vs Index {idx2} (Label: {original_label2})")

            # --- Actual Gemini Call ---
            # winner_number = ask_gemini_which_is_more_factual(text1, text2, gemini_llm_model)
            # For testing without real API calls, use a mock:
            winner_number = ask_gemini_which_is_more_factual(text1, text2, gemini_llm_model)
           

            if winner_number == 1:
                wins[idx1] += 1
            elif winner_number == 2:
                wins[idx2] += 1
            else:
                # Handle cases where Gemini couldn't decide or there was an error
                print(f"Skipping pair ({idx1}, {idx2}) due to ambiguous/failed Gemini response in round {round_num+1}.")
                continue # Or implement retry logic

            comparisons_made[idx1] += 1
            comparisons_made[idx2] += 1
            # time.sleep(1) # Add delay if needed for API rate limits

print("\n--- Tournament Finished ---")

# --- Select Top 100 (with tie-breaking) ---
sorted_indices_by_wins = sorted(indices, key=lambda i: wins[i], reverse=True)

top_100_final_indices = []
num_selected = 0
# Get unique win counts in descending order
unique_win_scores = sorted(list(set(wins.values())), reverse=True)

for score in unique_win_scores:
    if num_selected == 100:
        break
    
    # Collect all abstracts that achieved this score
    abstracts_with_this_score = [idx for idx in sorted_indices_by_wins if wins[idx] == score]
    
    if num_selected + len(abstracts_with_this_score) <= 100:
        # If we can take all abstracts with this score without exceeding 100
        top_100_final_indices.extend(abstracts_with_this_score)
        num_selected += len(abstracts_with_this_score)
    else:
        # This score group straddles the 100 mark, need to pick randomly
        needed = 100 - num_selected
        random.shuffle(abstracts_with_this_score) # Shuffle for random selection
        top_100_final_indices.extend(abstracts_with_this_score[:needed])
        num_selected += needed
        break # We have reached 100

top_100_abstracts_data = [(combined_abstracts[i][0], combined_abstracts[i][1], wins[i]) for i in top_100_final_indices]

print("\n--- Top 100 Selected Abstracts (Label, Text, Wins) ---")
for i, (label, text, win_count) in enumerate(top_100_abstracts_data):
    print(f"{i+1}. Index: {top_100_final_indices[i]}, Original Label: {label}, Wins: {win_count}, Text: {text[:100].strip()}...")

# Optional: Analyze the distribution of original labels in the top 100
real_in_top_100 = sum(1 for label, _, _ in top_100_abstracts_data if label == "real")
gen_in_top_100 = sum(1 for label, _, _ in top_100_abstracts_data if label == "gen")
print(f"\nComposition of Top 100: Real abstracts: {real_in_top_100}, Generated abstracts: {gen_in_top_100}")
print(f"\nWin counts distribution for all abstracts: {sorted(wins.items(), key=lambda item: item[1], reverse=True)}")
# print(f"Comparisons per abstract: {comparisons_made}")
# Out:
# Starting tournament. Total abstracts: 224. Rounds (K): 5
#
# --- Tournament Round 1 of 5 ---
# Comparing pair: Index 102 (Label: real) vs Index 198 (Label: gen)
# Comparing pair: Index 161 (Label: real) vs Index 120 (Label: gen)
# Comparing pair: Index 138 (Label: gen) vs Index 87 (Label: gen)
# Comparing pair: Index 51 (Label: gen) vs Index 103 (Label: gen)
# Comparing pair: Index 94 (Label: real) vs Index 17 (Label: real)
# Comparing pair: Index 104 (Label: real) vs Index 38 (Label: gen)
# Comparing pair: Index 176 (Label: real) vs Index 183 (Label: real)
# Comparing pair: Index 16 (Label: real) vs Index 125 (Label: real)
# Warning: Ambiguous Gemini response: Please provide Abstract 1 and Abstract 2.
#
# Skipping pair (16, 125) due to ambiguous/failed Gemini response in round 1.
# Comparing pair: Index 56 (Label: gen) vs Index 63 (Label: real)
# Comparing pair: Index 134 (Label: real) vs Index 90 (Label: real)
# Comparing pair: Index 131 (Label: real) vs Index 127 (Label: gen)
# Comparing pair: Index 32 (Label: gen) vs Index 121 (Label: real)
# Comparing pair: Index 75 (Label: gen) vs Index 9 (Label: gen)
# Comparing pair: Index 83 (Label: gen) vs Index 218 (Label: gen)
# Comparing pair: Index 2 (Label: gen) vs Index 10 (Label: gen)
# Comparing pair: Index 25 (Label: real) vs Index 4 (Label: gen)
# Comparing pair: Index 105 (Label: real) vs Index 217 (Label: real)
# Comparing pair: Index 70 (Label: real) vs Index 43 (Label: gen)
# Comparing pair: Index 60 (Label: real) vs Index 58 (Label: gen)
# Comparing pair: Index 174 (Label: gen) vs Index 132 (Label: gen)
# Comparing pair: Index 209 (Label: real) vs Index 86 (Label: gen)
# Comparing pair: Index 158 (Label: real) vs Index 166 (Label: real)
# Comparing pair: Index 115 (Label: real) vs Index 52 (Label: gen)
# Comparing pair: Index 71 (Label: real) vs Index 93 (Label: gen)
# Comparing pair: Index 142 (Label: gen) vs Index 57 (Label: real)
# Comparing pair: Index 15 (Label: real) vs Index 11 (Label: real)
# Comparing pair: Index 201 (Label: gen) vs Index 149 (Label: gen)
# Comparing pair: Index 160 (Label: gen) vs Index 85 (Label: real)
# Comparing pair: Index 170 (Label: gen) vs Index 124 (Label: gen)
# Comparing pair: Index 151 (Label: real) vs Index 137 (Label: real)
# Comparing pair: Index 192 (Label: real) vs Index 172 (Label: gen)
# Comparing pair: Index 141 (Label: gen) vs Index 185 (Label: gen)
# Comparing pair: Index 187 (Label: real) vs Index 212 (Label: gen)
# Comparing pair: Index 163 (Label: gen) vs Index 33 (Label: gen)
# Comparing pair: Index 123 (Label: real) vs Index 92 (Label: gen)
# Comparing pair: Index 41 (Label: gen) vs Index 6 (Label: gen)
# Comparing pair: Index 55 (Label: real) vs Index 101 (Label: gen)
# Comparing pair: Index 65 (Label: real) vs Index 79 (Label: real)
# Comparing pair: Index 173 (Label: gen) vs Index 204 (Label: gen)
# Comparing pair: Index 193 (Label: gen) vs Index 155 (Label: real)
# Comparing pair: Index 34 (Label: real) vs Index 144 (Label: gen)
# Comparing pair: Index 164 (Label: real) vs Index 107 (Label: real)
# Comparing pair: Index 190 (Label: gen) vs Index 152 (Label: real)
# Comparing pair: Index 206 (Label: gen) vs Index 96 (Label: gen)
# Comparing pair: Index 153 (Label: gen) vs Index 140 (Label: gen)
# Comparing pair: Index 126 (Label: gen) vs Index 31 (Label: gen)
# Comparing pair: Index 97 (Label: gen) vs Index 210 (Label: gen)
# Comparing pair: Index 54 (Label: real) vs Index 181 (Label: gen)
# Comparing pair: Index 91 (Label: real) vs Index 118 (Label: real)
# Comparing pair: Index 27 (Label: gen) vs Index 221 (Label: gen)
# Comparing pair: Index 148 (Label: gen) vs Index 188 (Label: gen)
# Comparing pair: Index 145 (Label: gen) vs Index 49 (Label: real)
# Comparing pair: Index 0 (Label: gen) vs Index 171 (Label: real)
# Comparing pair: Index 111 (Label: gen) vs Index 220 (Label: gen)
# Comparing pair: Index 44 (Label: real) vs Index 73 (Label: real)
# Comparing pair: Index 68 (Label: gen) vs Index 200 (Label: gen)
# Comparing pair: Index 12 (Label: gen) vs Index 130 (Label: gen)
# Comparing pair: Index 114 (Label: real) vs Index 167 (Label: real)
# Comparing pair: Index 1 (Label: gen) vs Index 168 (Label: gen)
# Comparing pair: Index 14 (Label: real) vs Index 191 (Label: gen)
# Comparing pair: Index 162 (Label: real) vs Index 99 (Label: gen)
# Comparing pair: Index 36 (Label: real) vs Index 20 (Label: gen)
# Comparing pair: Index 66 (Label: gen) vs Index 81 (Label: gen)
# Comparing pair: Index 184 (Label: gen) vs Index 67 (Label: real)
# Comparing pair: Index 207 (Label: real) vs Index 214 (Label: real)
# Comparing pair: Index 196 (Label: gen) vs Index 150 (Label: real)
# Comparing pair: Index 48 (Label: gen) vs Index 195 (Label: gen)
# Comparing pair: Index 208 (Label: gen) vs Index 154 (Label: real)
# Comparing pair: Index 69 (Label: real) vs Index 159 (Label: gen)
# Comparing pair: Index 28 (Label: real) vs Index 98 (Label: gen)
# Comparing pair: Index 112 (Label: real) vs Index 139 (Label: real)
# Comparing pair: Index 3 (Label: gen) vs Index 143 (Label: real)
# Comparing pair: Index 108 (Label: real) vs Index 22 (Label: gen)
# Comparing pair: Index 219 (Label: real) vs Index 128 (Label: gen)
# Comparing pair: Index 156 (Label: gen) vs Index 37 (Label: gen)
# Comparing pair: Index 216 (Label: gen) vs Index 177 (Label: real)
# Comparing pair: Index 165 (Label: gen) vs Index 72 (Label: gen)
# Comparing pair: Index 39 (Label: gen) vs Index 202 (Label: gen)
# Comparing pair: Index 100 (Label: real) vs Index 40 (Label: gen)
# Comparing pair: Index 175 (Label: real) vs Index 157 (Label: real)
# Comparing pair: Index 53 (Label: real) vs Index 179 (Label: gen)
# Comparing pair: Index 74 (Label: real) vs Index 30 (Label: gen)
# Comparing pair: Index 133 (Label: real) vs Index 129 (Label: gen)
# Comparing pair: Index 47 (Label: real) vs Index 19 (Label: gen)
# Comparing pair: Index 26 (Label: gen) vs Index 84 (Label: gen)
# Comparing pair: Index 50 (Label: gen) vs Index 223 (Label: gen)
# Comparing pair: Index 23 (Label: real) vs Index 119 (Label: gen)
# Comparing pair: Index 215 (Label: real) vs Index 122 (Label: real)
# Comparing pair: Index 45 (Label: real) vs Index 62 (Label: real)
# Comparing pair: Index 213 (Label: gen) vs Index 189 (Label: gen)
# Comparing pair: Index 110 (Label: real) vs Index 78 (Label: real)
# Comparing pair: Index 197 (Label: real) vs Index 180 (Label: gen)
# Comparing pair: Index 46 (Label: gen) vs Index 135 (Label: real)
# Comparing pair: Index 106 (Label: real) vs Index 199 (Label: real)
# Comparing pair: Index 7 (Label: gen) vs Index 77 (Label: gen)
# Comparing pair: Index 29 (Label: real) vs Index 136 (Label: gen)
# Comparing pair: Index 109 (Label: real) vs Index 8 (Label: real)
# Comparing pair: Index 88 (Label: real) vs Index 178 (Label: gen)
# Comparing pair: Index 203 (Label: real) vs Index 186 (Label: real)
# Comparing pair: Index 116 (Label: gen) vs Index 5 (Label: gen)
# Comparing pair: Index 18 (Label: gen) vs Index 211 (Label: real)
# Comparing pair: Index 76 (Label: gen) vs Index 24 (Label: gen)
# Comparing pair: Index 42 (Label: gen) vs Index 95 (Label: gen)
# Comparing pair: Index 21 (Label: gen) vs Index 205 (Label: real)
# Comparing pair: Index 80 (Label: gen) vs Index 117 (Label: gen)
# Comparing pair: Index 113 (Label: real) vs Index 147 (Label: real)
# Comparing pair: Index 61 (Label: gen) vs Index 89 (Label: real)
# Comparing pair: Index 169 (Label: gen) vs Index 146 (Label: real)
# Comparing pair: Index 64 (Label: gen) vs Index 59 (Label: real)
# Comparing pair: Index 222 (Label: real) vs Index 182 (Label: real)
# Comparing pair: Index 13 (Label: gen) vs Index 194 (Label: gen)
# Comparing pair: Index 35 (Label: gen) vs Index 82 (Label: real)
#
# --- Tournament Round 2 of 5 ---
# Comparing pair: Index 159 (Label: gen) vs Index 52 (Label: gen)
# Comparing pair: Index 31 (Label: gen) vs Index 40 (Label: gen)
# Comparing pair: Index 100 (Label: real) vs Index 129 (Label: gen)
# Comparing pair: Index 6 (Label: gen) vs Index 20 (Label: gen)
# Comparing pair: Index 19 (Label: gen) vs Index 66 (Label: gen)
# Comparing pair: Index 217 (Label: real) vs Index 87 (Label: gen)
# Comparing pair: Index 30 (Label: gen) vs Index 107 (Label: real)
# Comparing pair: Index 189 (Label: gen) vs Index 113 (Label: real)
# Comparing pair: Index 34 (Label: real) vs Index 177 (Label: real)
# Comparing pair: Index 207 (Label: real) vs Index 82 (Label: real)
# Comparing pair: Index 69 (Label: real) vs Index 118 (Label: real)
# Comparing pair: Index 145 (Label: gen) vs Index 112 (Label: real)
# Comparing pair: Index 32 (Label: gen) vs Index 92 (Label: gen)
# Comparing pair: Index 191 (Label: gen) vs Index 139 (Label: real)
# Comparing pair: Index 117 (Label: gen) vs Index 204 (Label: gen)
# Comparing pair: Index 196 (Label: gen) vs Index 214 (Label: real)
# Comparing pair: Index 195 (Label: gen) vs Index 221 (Label: gen)
# Comparing pair: Index 61 (Label: gen) vs Index 48 (Label: gen)
# Comparing pair: Index 115 (Label: real) vs Index 201 (Label: gen)
# Comparing pair: Index 26 (Label: gen) vs Index 91 (Label: real)
# Comparing pair: Index 75 (Label: gen) vs Index 134 (Label: real)
# Comparing pair: Index 27 (Label: gen) vs Index 25 (Label: real)
# Comparing pair: Index 98 (Label: gen) vs Index 182 (Label: real)
# Comparing pair: Index 169 (Label: gen) vs Index 93 (Label: gen)
# Comparing pair: Index 223 (Label: gen) vs Index 39 (Label: gen)
# Comparing pair: Index 10 (Label: gen) vs Index 202 (Label: gen)
# Comparing pair: Index 65 (Label: real) vs Index 0 (Label: gen)
# Comparing pair: Index 51 (Label: gen) vs Index 135 (Label: real)
# Comparing pair: Index 138 (Label: gen) vs Index 142 (Label: gen)
# Comparing pair: Index 125 (Label: real) vs Index 205 (Label: real)
# Comparing pair: Index 141 (Label: gen) vs Index 133 (Label: real)
# Comparing pair: Index 67 (Label: real) vs Index 157 (Label: real)
# Comparing pair: Index 116 (Label: gen) vs Index 76 (Label: gen)
# Comparing pair: Index 220 (Label: gen) vs Index 148 (Label: gen)
# Comparing pair: Index 85 (Label: real) vs Index 153 (Label: gen)
# Comparing pair: Index 86 (Label: gen) vs Index 84 (Label: gen)
# Comparing pair: Index 102 (Label: real) vs Index 103 (Label: gen)
# Comparing pair: Index 60 (Label: real) vs Index 167 (Label: real)
# Comparing pair: Index 175 (Label: real) vs Index 128 (Label: gen)
# Comparing pair: Index 192 (Label: real) vs Index 179 (Label: gen)
# Comparing pair: Index 176 (Label: real) vs Index 216 (Label: gen)
# Comparing pair: Index 144 (Label: gen) vs Index 59 (Label: real)
# Comparing pair: Index 165 (Label: gen) vs Index 44 (Label: real)
# Comparing pair: Index 215 (Label: real) vs Index 88 (Label: real)
# Comparing pair: Index 124 (Label: gen) vs Index 218 (Label: gen)
# Comparing pair: Index 99 (Label: gen) vs Index 56 (Label: gen)
# Comparing pair: Index 73 (Label: real) vs Index 77 (Label: gen)
# Comparing pair: Index 97 (Label: gen) vs Index 178 (Label: gen)
# Comparing pair: Index 80 (Label: gen) vs Index 11 (Label: real)
# Comparing pair: Index 152 (Label: real) vs Index 198 (Label: gen)
# Comparing pair: Index 132 (Label: gen) vs Index 83 (Label: gen)
# Comparing pair: Index 29 (Label: real) vs Index 146 (Label: real)
# Comparing pair: Index 43 (Label: gen) vs Index 36 (Label: real)
# Comparing pair: Index 95 (Label: gen) vs Index 42 (Label: gen)
# Comparing pair: Index 158 (Label: real) vs Index 111 (Label: gen)
# Comparing pair: Index 188 (Label: gen) vs Index 106 (Label: real)
# Comparing pair: Index 16 (Label: real) vs Index 156 (Label: gen)
# Comparing pair: Index 105 (Label: real) vs Index 57 (Label: real)
# Comparing pair: Index 5 (Label: gen) vs Index 140 (Label: gen)
# Comparing pair: Index 137 (Label: real) vs Index 164 (Label: real)
# Comparing pair: Index 119 (Label: gen) vs Index 211 (Label: real)
# Comparing pair: Index 127 (Label: gen) vs Index 185 (Label: gen)
# Comparing pair: Index 206 (Label: gen) vs Index 186 (Label: real)
# Comparing pair: Index 7 (Label: gen) vs Index 89 (Label: real)
# Comparing pair: Index 3 (Label: gen) vs Index 154 (Label: real)
# Comparing pair: Index 130 (Label: gen) vs Index 49 (Label: real)
# Comparing pair: Index 17 (Label: real) vs Index 161 (Label: real)
# Comparing pair: Index 183 (Label: real) vs Index 22 (Label: gen)
# Comparing pair: Index 174 (Label: gen) vs Index 13 (Label: gen)
# Comparing pair: Index 47 (Label: real) vs Index 208 (Label: gen)
# Comparing pair: Index 23 (Label: real) vs Index 200 (Label: gen)
# Comparing pair: Index 212 (Label: gen) vs Index 123 (Label: real)
# Comparing pair: Index 122 (Label: real) vs Index 12 (Label: gen)
# Comparing pair: Index 193 (Label: gen) vs Index 181 (Label: gen)
# Comparing pair: Index 18 (Label: gen) vs Index 162 (Label: real)
# Comparing pair: Index 170 (Label: gen) vs Index 78 (Label: real)
# Comparing pair: Index 180 (Label: gen) vs Index 147 (Label: real)
# Comparing pair: Index 1 (Label: gen) vs Index 9 (Label: gen)
# Comparing pair: Index 68 (Label: gen) vs Index 4 (Label: gen)
# Comparing pair: Index 143 (Label: real) vs Index 74 (Label: real)
# Comparing pair: Index 45 (Label: real) vs Index 63 (Label: real)
# Comparing pair: Index 70 (Label: real) vs Index 8 (Label: real)
# Comparing pair: Index 166 (Label: real) vs Index 46 (Label: gen)
# Comparing pair: Index 173 (Label: gen) vs Index 213 (Label: gen)
# Comparing pair: Index 168 (Label: gen) vs Index 71 (Label: real)
# Comparing pair: Index 54 (Label: real) vs Index 155 (Label: real)
# Comparing pair: Index 136 (Label: gen) vs Index 184 (Label: gen)
# Comparing pair: Index 210 (Label: gen) vs Index 121 (Label: real)
# Comparing pair: Index 219 (Label: real) vs Index 64 (Label: gen)
# Comparing pair: Index 150 (Label: real) vs Index 172 (Label: gen)
# Comparing pair: Index 38 (Label: gen) vs Index 14 (Label: real)
# Comparing pair: Index 149 (Label: gen) vs Index 109 (Label: real)
# Comparing pair: Index 2 (Label: gen) vs Index 131 (Label: real)
# Comparing pair: Index 197 (Label: real) vs Index 108 (Label: real)
# Comparing pair: Index 163 (Label: gen) vs Index 55 (Label: real)
# Comparing pair: Index 190 (Label: gen) vs Index 199 (Label: real)
# Comparing pair: Index 194 (Label: gen) vs Index 21 (Label: gen)
# Comparing pair: Index 53 (Label: real) vs Index 33 (Label: gen)
# Comparing pair: Index 126 (Label: gen) vs Index 50 (Label: gen)
# Comparing pair: Index 79 (Label: real) vs Index 94 (Label: real)
# Comparing pair: Index 171 (Label: real) vs Index 104 (Label: real)
# Comparing pair: Index 222 (Label: real) vs Index 151 (Label: real)
# Comparing pair: Index 96 (Label: gen) vs Index 24 (Label: gen)
# Comparing pair: Index 15 (Label: real) vs Index 41 (Label: gen)
# Comparing pair: Index 203 (Label: real) vs Index 110 (Label: real)
# Comparing pair: Index 37 (Label: gen) vs Index 62 (Label: real)
# Comparing pair: Index 114 (Label: real) vs Index 90 (Label: real)
# Comparing pair: Index 160 (Label: gen) vs Index 101 (Label: gen)
# Comparing pair: Index 209 (Label: real) vs Index 81 (Label: gen)
# Comparing pair: Index 28 (Label: real) vs Index 120 (Label: gen)
# Comparing pair: Index 72 (Label: gen) vs Index 58 (Label: gen)
# Comparing pair: Index 187 (Label: real) vs Index 35 (Label: gen)
#
# --- Tournament Round 3 of 5 ---
# Comparing pair: Index 137 (Label: real) vs Index 206 (Label: gen)
# Comparing pair: Index 93 (Label: gen) vs Index 170 (Label: gen)
# Comparing pair: Index 37 (Label: gen) vs Index 107 (Label: real)
# Comparing pair: Index 189 (Label: gen) vs Index 121 (Label: real)
# Comparing pair: Index 210 (Label: gen) vs Index 33 (Label: gen)
# Comparing pair: Index 153 (Label: gen) vs Index 35 (Label: gen)
# Comparing pair: Index 221 (Label: gen) vs Index 178 (Label: gen)
# Comparing pair: Index 36 (Label: real) vs Index 14 (Label: real)
# Comparing pair: Index 69 (Label: real) vs Index 202 (Label: gen)
# Comparing pair: Index 109 (Label: real) vs Index 31 (Label: gen)
# Comparing pair: Index 81 (Label: gen) vs Index 103 (Label: gen)
# Comparing pair: Index 124 (Label: gen) vs Index 10 (Label: gen)
# Comparing pair: Index 80 (Label: gen) vs Index 161 (Label: real)
# Comparing pair: Index 8 (Label: real) vs Index 220 (Label: gen)
# Comparing pair: Index 217 (Label: real) vs Index 22 (Label: gen)
# Comparing pair: Index 3 (Label: gen) vs Index 72 (Label: gen)
# Comparing pair: Index 101 (Label: gen) vs Index 54 (Label: real)
# Comparing pair: Index 133 (Label: real) vs Index 56 (Label: gen)
# Comparing pair: Index 194 (Label: gen) vs Index 214 (Label: real)
# Comparing pair: Index 208 (Label: gen) vs Index 2 (Label: gen)
# Comparing pair: Index 79 (Label: real) vs Index 45 (Label: real)
# Comparing pair: Index 11 (Label: real) vs Index 29 (Label: real)
# Comparing pair: Index 207 (Label: real) vs Index 131 (Label: real)
# Comparing pair: Index 39 (Label: gen) vs Index 85 (Label: real)
# Comparing pair: Index 90 (Label: real) vs Index 105 (Label: real)
# Comparing pair: Index 23 (Label: real) vs Index 50 (Label: gen)
# Comparing pair: Index 195 (Label: gen) vs Index 185 (Label: gen)
# Comparing pair: Index 136 (Label: gen) vs Index 192 (Label: real)
# Comparing pair: Index 155 (Label: real) vs Index 44 (Label: real)
# Comparing pair: Index 108 (Label: real) vs Index 112 (Label: real)
# Comparing pair: Index 74 (Label: real) vs Index 27 (Label: gen)
# Comparing pair: Index 154 (Label: real) vs Index 16 (Label: real)
# Comparing pair: Index 125 (Label: real) vs Index 176 (Label: real)
# Comparing pair: Index 173 (Label: gen) vs Index 181 (Label: gen)
# Comparing pair: Index 166 (Label: real) vs Index 218 (Label: gen)
# Comparing pair: Index 159 (Label: gen) vs Index 67 (Label: real)
# Comparing pair: Index 97 (Label: gen) vs Index 49 (Label: real)
# Comparing pair: Index 94 (Label: real) vs Index 127 (Label: gen)
# Comparing pair: Index 15 (Label: real) vs Index 122 (Label: real)
# Comparing pair: Index 141 (Label: gen) vs Index 30 (Label: gen)
# Comparing pair: Index 132 (Label: gen) vs Index 65 (Label: real)
# Comparing pair: Index 172 (Label: gen) vs Index 140 (Label: gen)
# Comparing pair: Index 196 (Label: gen) vs Index 204 (Label: gen)
# Comparing pair: Index 113 (Label: real) vs Index 71 (Label: real)
# Comparing pair: Index 118 (Label: real) vs Index 91 (Label: real)
# Comparing pair: Index 62 (Label: real) vs Index 19 (Label: gen)
# Comparing pair: Index 145 (Label: gen) vs Index 174 (Label: gen)
# Comparing pair: Index 6 (Label: gen) vs Index 119 (Label: gen)
# Comparing pair: Index 84 (Label: gen) vs Index 73 (Label: real)
# Comparing pair: Index 76 (Label: gen) vs Index 82 (Label: real)
# Comparing pair: Index 89 (Label: real) vs Index 175 (Label: real)
# Comparing pair: Index 219 (Label: real) vs Index 20 (Label: gen)
# Comparing pair: Index 38 (Label: gen) vs Index 184 (Label: gen)
# Comparing pair: Index 216 (Label: gen) vs Index 147 (Label: real)
# Comparing pair: Index 98 (Label: gen) vs Index 28 (Label: real)
# Comparing pair: Index 55 (Label: real) vs Index 211 (Label: real)
# Comparing pair: Index 96 (Label: gen) vs Index 197 (Label: real)
# Comparing pair: Index 222 (Label: real) vs Index 18 (Label: gen)
# Comparing pair: Index 47 (Label: real) vs Index 60 (Label: real)
# Comparing pair: Index 209 (Label: real) vs Index 12 (Label: gen)
# Comparing pair: Index 198 (Label: gen) vs Index 25 (Label: real)
# Comparing pair: Index 151 (Label: real) vs Index 134 (Label: real)
# Comparing pair: Index 95 (Label: gen) vs Index 51 (Label: gen)
# Comparing pair: Index 83 (Label: gen) vs Index 177 (Label: real)
# Comparing pair: Index 146 (Label: real) vs Index 114 (Label: real)
# Comparing pair: Index 193 (Label: gen) vs Index 48 (Label: gen)
# Comparing pair: Index 156 (Label: gen) vs Index 139 (Label: real)
# Comparing pair: Index 169 (Label: gen) vs Index 86 (Label: gen)
# Comparing pair: Index 138 (Label: gen) vs Index 117 (Label: gen)
# Comparing pair: Index 123 (Label: real) vs Index 190 (Label: gen)
# Comparing pair: Index 111 (Label: gen) vs Index 41 (Label: gen)
# Comparing pair: Index 102 (Label: real) vs Index 158 (Label: real)
# Comparing pair: Index 4 (Label: gen) vs Index 165 (Label: gen)
# Comparing pair: Index 120 (Label: gen) vs Index 187 (Label: real)
# Comparing pair: Index 152 (Label: real) vs Index 183 (Label: real)
# Comparing pair: Index 191 (Label: gen) vs Index 180 (Label: gen)
# Comparing pair: Index 223 (Label: gen) vs Index 126 (Label: gen)
# Comparing pair: Index 21 (Label: gen) vs Index 162 (Label: real)
# Comparing pair: Index 167 (Label: real) vs Index 150 (Label: real)
# Comparing pair: Index 64 (Label: gen) vs Index 77 (Label: gen)
# Comparing pair: Index 53 (Label: real) vs Index 24 (Label: gen)
# Comparing pair: Index 7 (Label: gen) vs Index 186 (Label: real)
# Comparing pair: Index 92 (Label: gen) vs Index 188 (Label: gen)
# Comparing pair: Index 57 (Label: real) vs Index 106 (Label: real)
# Comparing pair: Index 215 (Label: real) vs Index 87 (Label: gen)
# Comparing pair: Index 17 (Label: real) vs Index 66 (Label: gen)
# Comparing pair: Index 61 (Label: gen) vs Index 157 (Label: real)
# Comparing pair: Index 128 (Label: gen) vs Index 135 (Label: real)
# Comparing pair: Index 168 (Label: gen) vs Index 43 (Label: gen)
# Comparing pair: Index 182 (Label: real) vs Index 5 (Label: gen)
# Comparing pair: Index 9 (Label: gen) vs Index 199 (Label: real)
# Comparing pair: Index 110 (Label: real) vs Index 213 (Label: gen)
# Comparing pair: Index 143 (Label: real) vs Index 115 (Label: real)
# Comparing pair: Index 149 (Label: gen) vs Index 201 (Label: gen)
# Comparing pair: Index 59 (Label: real) vs Index 205 (Label: real)
# Comparing pair: Index 200 (Label: gen) vs Index 142 (Label: gen)
# Comparing pair: Index 100 (Label: real) vs Index 1 (Label: gen)
# Comparing pair: Index 63 (Label: real) vs Index 171 (Label: real)
# Comparing pair: Index 203 (Label: real) vs Index 46 (Label: gen)
# Comparing pair: Index 160 (Label: gen) vs Index 104 (Label: real)
# Comparing pair: Index 52 (Label: gen) vs Index 144 (Label: gen)
# Comparing pair: Index 26 (Label: gen) vs Index 42 (Label: gen)
# Comparing pair: Index 130 (Label: gen) vs Index 34 (Label: real)
# Comparing pair: Index 32 (Label: gen) vs Index 78 (Label: real)
# Comparing pair: Index 58 (Label: gen) vs Index 99 (Label: gen)
# Comparing pair: Index 164 (Label: real) vs Index 212 (Label: gen)
# Comparing pair: Index 88 (Label: real) vs Index 68 (Label: gen)
# Comparing pair: Index 116 (Label: gen) vs Index 40 (Label: gen)
# Comparing pair: Index 13 (Label: gen) vs Index 163 (Label: gen)
# Comparing pair: Index 70 (Label: real) vs Index 129 (Label: gen)
# Comparing pair: Index 75 (Label: gen) vs Index 179 (Label: gen)
# Comparing pair: Index 0 (Label: gen) vs Index 148 (Label: gen)
#
# --- Tournament Round 4 of 5 ---
# Comparing pair: Index 77 (Label: gen) vs Index 51 (Label: gen)
# Comparing pair: Index 153 (Label: gen) vs Index 113 (Label: real)
# Comparing pair: Index 91 (Label: real) vs Index 6 (Label: gen)
# Comparing pair: Index 76 (Label: gen) vs Index 149 (Label: gen)
# Comparing pair: Index 24 (Label: gen) vs Index 115 (Label: real)
# Comparing pair: Index 52 (Label: gen) vs Index 111 (Label: gen)
# Comparing pair: Index 17 (Label: real) vs Index 207 (Label: real)
# Comparing pair: Index 73 (Label: real) vs Index 208 (Label: gen)
# Comparing pair: Index 0 (Label: gen) vs Index 94 (Label: real)
# Comparing pair: Index 174 (Label: gen) vs Index 200 (Label: gen)
# Comparing pair: Index 41 (Label: gen) vs Index 151 (Label: real)
# Comparing pair: Index 31 (Label: gen) vs Index 47 (Label: real)
# Comparing pair: Index 80 (Label: gen) vs Index 45 (Label: real)
# Comparing pair: Index 39 (Label: gen) vs Index 223 (Label: gen)
# Comparing pair: Index 101 (Label: gen) vs Index 197 (Label: real)
# Comparing pair: Index 133 (Label: real) vs Index 4 (Label: gen)
# Comparing pair: Index 53 (Label: real) vs Index 123 (Label: real)
# Comparing pair: Index 186 (Label: real) vs Index 216 (Label: gen)
# Comparing pair: Index 121 (Label: real) vs Index 178 (Label: gen)
# Comparing pair: Index 189 (Label: gen) vs Index 212 (Label: gen)
# Comparing pair: Index 8 (Label: real) vs Index 210 (Label: gen)
# Comparing pair: Index 13 (Label: gen) vs Index 72 (Label: gen)
# Comparing pair: Index 126 (Label: gen) vs Index 165 (Label: gen)
# Comparing pair: Index 65 (Label: real) vs Index 64 (Label: gen)
# Comparing pair: Index 168 (Label: gen) vs Index 176 (Label: real)
# Comparing pair: Index 142 (Label: gen) vs Index 58 (Label: gen)
# Comparing pair: Index 169 (Label: gen) vs Index 173 (Label: gen)
# Comparing pair: Index 195 (Label: gen) vs Index 206 (Label: gen)
# Comparing pair: Index 187 (Label: real) vs Index 148 (Label: gen)
# Comparing pair: Index 18 (Label: gen) vs Index 27 (Label: gen)
# Comparing pair: Index 162 (Label: real) vs Index 203 (Label: real)
# Comparing pair: Index 54 (Label: real) vs Index 36 (Label: real)
# Comparing pair: Index 35 (Label: gen) vs Index 172 (Label: gen)
# Comparing pair: Index 143 (Label: real) vs Index 161 (Label: real)
# Comparing pair: Index 156 (Label: gen) vs Index 166 (Label: real)
# Comparing pair: Index 158 (Label: real) vs Index 87 (Label: gen)
# Comparing pair: Index 120 (Label: gen) vs Index 179 (Label: gen)
# Comparing pair: Index 177 (Label: real) vs Index 42 (Label: gen)
# Comparing pair: Index 30 (Label: gen) vs Index 60 (Label: real)
# Comparing pair: Index 136 (Label: gen) vs Index 33 (Label: gen)
# Comparing pair: Index 55 (Label: real) vs Index 221 (Label: gen)
# Comparing pair: Index 96 (Label: gen) vs Index 90 (Label: real)
# Comparing pair: Index 19 (Label: gen) vs Index 219 (Label: real)
# Comparing pair: Index 217 (Label: real) vs Index 78 (Label: real)
# Comparing pair: Index 201 (Label: gen) vs Index 192 (Label: real)
# Comparing pair: Index 43 (Label: gen) vs Index 20 (Label: gen)
# Comparing pair: Index 62 (Label: real) vs Index 205 (Label: real)
# Comparing pair: Index 140 (Label: gen) vs Index 122 (Label: real)
# Comparing pair: Index 109 (Label: real) vs Index 95 (Label: gen)
# Comparing pair: Index 44 (Label: real) vs Index 218 (Label: gen)
# Comparing pair: Index 188 (Label: gen) vs Index 107 (Label: real)
# Comparing pair: Index 34 (Label: real) vs Index 105 (Label: real)
# Comparing pair: Index 150 (Label: real) vs Index 129 (Label: gen)
# Comparing pair: Index 86 (Label: gen) vs Index 46 (Label: gen)
# Comparing pair: Index 167 (Label: real) vs Index 134 (Label: real)
# Comparing pair: Index 119 (Label: gen) vs Index 135 (Label: real)
# Comparing pair: Index 103 (Label: gen) vs Index 37 (Label: gen)
# Comparing pair: Index 84 (Label: gen) vs Index 14 (Label: real)
# Comparing pair: Index 116 (Label: gen) vs Index 49 (Label: real)
# Comparing pair: Index 190 (Label: gen) vs Index 220 (Label: gen)
# Comparing pair: Index 110 (Label: real) vs Index 7 (Label: gen)
# Comparing pair: Index 132 (Label: gen) vs Index 185 (Label: gen)
# Comparing pair: Index 66 (Label: gen) vs Index 88 (Label: real)
# Comparing pair: Index 194 (Label: gen) vs Index 215 (Label: real)
# Comparing pair: Index 106 (Label: real) vs Index 131 (Label: real)
# Comparing pair: Index 15 (Label: real) vs Index 70 (Label: real)
# Comparing pair: Index 222 (Label: real) vs Index 74 (Label: real)
# Comparing pair: Index 139 (Label: real) vs Index 146 (Label: real)
# Comparing pair: Index 3 (Label: gen) vs Index 56 (Label: gen)
# Comparing pair: Index 29 (Label: real) vs Index 202 (Label: gen)
# Comparing pair: Index 155 (Label: real) vs Index 100 (Label: real)
# Comparing pair: Index 11 (Label: real) vs Index 114 (Label: real)
# Comparing pair: Index 108 (Label: real) vs Index 26 (Label: gen)
# Comparing pair: Index 12 (Label: gen) vs Index 104 (Label: real)
# Comparing pair: Index 10 (Label: gen) vs Index 23 (Label: real)
# Comparing pair: Index 183 (Label: real) vs Index 138 (Label: gen)
# Comparing pair: Index 50 (Label: gen) vs Index 214 (Label: real)
# Comparing pair: Index 89 (Label: real) vs Index 59 (Label: real)
# Comparing pair: Index 163 (Label: gen) vs Index 28 (Label: real)
# Comparing pair: Index 213 (Label: gen) vs Index 2 (Label: gen)
# Comparing pair: Index 184 (Label: gen) vs Index 38 (Label: gen)
# Comparing pair: Index 97 (Label: gen) vs Index 160 (Label: gen)
# Comparing pair: Index 16 (Label: real) vs Index 175 (Label: real)
# Comparing pair: Index 1 (Label: gen) vs Index 141 (Label: gen)
# Comparing pair: Index 71 (Label: real) vs Index 198 (Label: gen)
# Comparing pair: Index 137 (Label: real) vs Index 57 (Label: real)
# Comparing pair: Index 22 (Label: gen) vs Index 21 (Label: gen)
# Comparing pair: Index 102 (Label: real) vs Index 9 (Label: gen)
# Comparing pair: Index 93 (Label: gen) vs Index 92 (Label: gen)
# Comparing pair: Index 125 (Label: real) vs Index 193 (Label: gen)
# Comparing pair: Index 159 (Label: gen) vs Index 147 (Label: real)
# Comparing pair: Index 117 (Label: gen) vs Index 196 (Label: gen)
# Comparing pair: Index 40 (Label: gen) vs Index 182 (Label: real)
# Comparing pair: Index 171 (Label: real) vs Index 170 (Label: gen)
# Comparing pair: Index 67 (Label: real) vs Index 130 (Label: gen)
# Comparing pair: Index 209 (Label: real) vs Index 118 (Label: real)
# Comparing pair: Index 199 (Label: real) vs Index 191 (Label: gen)
# Comparing pair: Index 98 (Label: gen) vs Index 145 (Label: gen)
# Comparing pair: Index 204 (Label: gen) vs Index 128 (Label: gen)
# Comparing pair: Index 63 (Label: real) vs Index 157 (Label: real)
# Comparing pair: Index 81 (Label: gen) vs Index 69 (Label: real)
# Comparing pair: Index 124 (Label: gen) vs Index 127 (Label: gen)
# Comparing pair: Index 154 (Label: real) vs Index 211 (Label: real)
# Comparing pair: Index 112 (Label: real) vs Index 82 (Label: real)
# Comparing pair: Index 152 (Label: real) vs Index 99 (Label: gen)
# Comparing pair: Index 79 (Label: real) vs Index 32 (Label: gen)
# Comparing pair: Index 85 (Label: real) vs Index 83 (Label: gen)
# Comparing pair: Index 61 (Label: gen) vs Index 144 (Label: gen)
# Comparing pair: Index 5 (Label: gen) vs Index 75 (Label: gen)
# Comparing pair: Index 181 (Label: gen) vs Index 48 (Label: gen)
# Comparing pair: Index 68 (Label: gen) vs Index 180 (Label: gen)
# Comparing pair: Index 164 (Label: real) vs Index 25 (Label: real)
#
# --- Tournament Round 5 of 5 ---
# Comparing pair: Index 97 (Label: gen) vs Index 175 (Label: real)
# Comparing pair: Index 59 (Label: real) vs Index 104 (Label: real)
# Comparing pair: Index 174 (Label: gen) vs Index 24 (Label: gen)
# Comparing pair: Index 183 (Label: real) vs Index 89 (Label: real)
# Comparing pair: Index 11 (Label: real) vs Index 53 (Label: real)
# Comparing pair: Index 42 (Label: gen) vs Index 13 (Label: gen)
# Comparing pair: Index 117 (Label: gen) vs Index 10 (Label: gen)
# Comparing pair: Index 15 (Label: real) vs Index 55 (Label: real)
# Comparing pair: Index 9 (Label: gen) vs Index 90 (Label: real)
# Comparing pair: Index 79 (Label: real) vs Index 111 (Label: gen)
# Comparing pair: Index 123 (Label: real) vs Index 141 (Label: gen)
# Comparing pair: Index 223 (Label: gen) vs Index 74 (Label: real)
# Comparing pair: Index 203 (Label: real) vs Index 150 (Label: real)
# Comparing pair: Index 119 (Label: gen) vs Index 126 (Label: gen)
# Comparing pair: Index 164 (Label: real) vs Index 19 (Label: gen)
# Comparing pair: Index 44 (Label: real) vs Index 61 (Label: gen)
# Comparing pair: Index 158 (Label: real) vs Index 84 (Label: gen)
# Comparing pair: Index 80 (Label: gen) vs Index 215 (Label: real)
# Comparing pair: Index 3 (Label: gen) vs Index 25 (Label: real)
# Comparing pair: Index 212 (Label: gen) vs Index 83 (Label: gen)
# Comparing pair: Index 146 (Label: real) vs Index 92 (Label: gen)
# Comparing pair: Index 36 (Label: real) vs Index 14 (Label: real)
# Comparing pair: Index 110 (Label: real) vs Index 109 (Label: real)
# Comparing pair: Index 130 (Label: gen) vs Index 124 (Label: gen)
# Comparing pair: Index 216 (Label: gen) vs Index 51 (Label: gen)
# Comparing pair: Index 209 (Label: real) vs Index 102 (Label: real)
# Comparing pair: Index 52 (Label: gen) vs Index 100 (Label: real)
# Comparing pair: Index 213 (Label: gen) vs Index 76 (Label: gen)
# Comparing pair: Index 176 (Label: real) vs Index 200 (Label: gen)
# Comparing pair: Index 221 (Label: gen) vs Index 49 (Label: real)
# Comparing pair: Index 178 (Label: gen) vs Index 88 (Label: real)
# Comparing pair: Index 152 (Label: real) vs Index 171 (Label: real)
# Comparing pair: Index 160 (Label: gen) vs Index 95 (Label: gen)
# Comparing pair: Index 62 (Label: real) vs Index 155 (Label: real)
# Comparing pair: Index 195 (Label: gen) vs Index 138 (Label: gen)
# Comparing pair: Index 190 (Label: gen) vs Index 63 (Label: real)
# Comparing pair: Index 28 (Label: real) vs Index 68 (Label: gen)
# Comparing pair: Index 116 (Label: gen) vs Index 127 (Label: gen)
# Comparing pair: Index 39 (Label: gen) vs Index 91 (Label: real)
# Comparing pair: Index 41 (Label: gen) vs Index 64 (Label: gen)
# Comparing pair: Index 157 (Label: real) vs Index 50 (Label: gen)
# Comparing pair: Index 220 (Label: gen) vs Index 143 (Label: real)
# Comparing pair: Index 163 (Label: gen) vs Index 103 (Label: gen)
# Comparing pair: Index 196 (Label: gen) vs Index 113 (Label: real)
# Comparing pair: Index 93 (Label: gen) vs Index 12 (Label: gen)
# Comparing pair: Index 54 (Label: real) vs Index 56 (Label: gen)
# Comparing pair: Index 198 (Label: gen) vs Index 182 (Label: real)
# Comparing pair: Index 222 (Label: real) vs Index 167 (Label: real)
# Comparing pair: Index 139 (Label: real) vs Index 43 (Label: gen)
# Comparing pair: Index 26 (Label: gen) vs Index 47 (Label: real)
# Comparing pair: Index 45 (Label: real) vs Index 161 (Label: real)
# Comparing pair: Index 108 (Label: real) vs Index 204 (Label: gen)
# Comparing pair: Index 170 (Label: gen) vs Index 192 (Label: real)
# Comparing pair: Index 34 (Label: real) vs Index 147 (Label: real)
# Comparing pair: Index 165 (Label: gen) vs Index 40 (Label: gen)
# Comparing pair: Index 21 (Label: gen) vs Index 173 (Label: gen)
# Comparing pair: Index 67 (Label: real) vs Index 82 (Label: real)
# Comparing pair: Index 94 (Label: real) vs Index 136 (Label: gen)
# Comparing pair: Index 8 (Label: real) vs Index 188 (Label: gen)
# Comparing pair: Index 131 (Label: real) vs Index 33 (Label: gen)
# Comparing pair: Index 96 (Label: gen) vs Index 211 (Label: real)
# Comparing pair: Index 172 (Label: gen) vs Index 133 (Label: real)
# Comparing pair: Index 22 (Label: gen) vs Index 156 (Label: gen)
# Comparing pair: Index 125 (Label: real) vs Index 106 (Label: real)
# Comparing pair: Index 72 (Label: gen) vs Index 189 (Label: gen)
# Comparing pair: Index 184 (Label: gen) vs Index 159 (Label: gen)
# Comparing pair: Index 0 (Label: gen) vs Index 85 (Label: real)
# Comparing pair: Index 194 (Label: gen) vs Index 73 (Label: real)
# Comparing pair: Index 70 (Label: real) vs Index 191 (Label: gen)
# Comparing pair: Index 168 (Label: gen) vs Index 66 (Label: gen)
# Comparing pair: Index 98 (Label: gen) vs Index 29 (Label: real)
# Comparing pair: Index 151 (Label: real) vs Index 101 (Label: gen)
# Comparing pair: Index 181 (Label: gen) vs Index 202 (Label: gen)
# Comparing pair: Index 135 (Label: real) vs Index 81 (Label: gen)
# Comparing pair: Index 57 (Label: real) vs Index 71 (Label: real)
# Comparing pair: Index 128 (Label: gen) vs Index 105 (Label: real)
# Comparing pair: Index 207 (Label: real) vs Index 65 (Label: real)
# Comparing pair: Index 118 (Label: real) vs Index 199 (Label: real)
# Comparing pair: Index 38 (Label: gen) vs Index 154 (Label: real)
# Comparing pair: Index 162 (Label: real) vs Index 120 (Label: gen)
# Comparing pair: Index 145 (Label: gen) vs Index 142 (Label: gen)
# Comparing pair: Index 69 (Label: real) vs Index 114 (Label: real)
# Comparing pair: Index 107 (Label: real) vs Index 86 (Label: gen)
# Comparing pair: Index 149 (Label: gen) vs Index 214 (Label: real)
# Comparing pair: Index 132 (Label: gen) vs Index 148 (Label: gen)
# Comparing pair: Index 30 (Label: gen) vs Index 32 (Label: gen)
# Comparing pair: Index 129 (Label: gen) vs Index 185 (Label: gen)
# Comparing pair: Index 20 (Label: gen) vs Index 35 (Label: gen)
# Comparing pair: Index 205 (Label: real) vs Index 18 (Label: gen)
# Comparing pair: Index 23 (Label: real) vs Index 140 (Label: gen)
# Comparing pair: Index 179 (Label: gen) vs Index 193 (Label: gen)
# Comparing pair: Index 186 (Label: real) vs Index 187 (Label: real)
# Comparing pair: Index 87 (Label: gen) vs Index 197 (Label: real)
# Comparing pair: Index 77 (Label: gen) vs Index 122 (Label: real)
# Comparing pair: Index 78 (Label: real) vs Index 27 (Label: gen)
# Comparing pair: Index 166 (Label: real) vs Index 7 (Label: gen)
# Comparing pair: Index 37 (Label: gen) vs Index 48 (Label: gen)
# Comparing pair: Index 6 (Label: gen) vs Index 1 (Label: gen)
# Comparing pair: Index 219 (Label: real) vs Index 218 (Label: gen)
# Comparing pair: Index 121 (Label: real) vs Index 206 (Label: gen)
# Comparing pair: Index 177 (Label: real) vs Index 2 (Label: gen)
# Comparing pair: Index 75 (Label: gen) vs Index 153 (Label: gen)
# Comparing pair: Index 112 (Label: real) vs Index 201 (Label: gen)
# Comparing pair: Index 210 (Label: gen) vs Index 5 (Label: gen)
# Comparing pair: Index 58 (Label: gen) vs Index 16 (Label: real)
# Comparing pair: Index 208 (Label: gen) vs Index 4 (Label: gen)
# Comparing pair: Index 60 (Label: real) vs Index 217 (Label: real)
# Comparing pair: Index 17 (Label: real) vs Index 169 (Label: gen)
# Comparing pair: Index 137 (Label: real) vs Index 31 (Label: gen)
# Comparing pair: Index 180 (Label: gen) vs Index 99 (Label: gen)
# Comparing pair: Index 134 (Label: real) vs Index 144 (Label: gen)
# Comparing pair: Index 46 (Label: gen) vs Index 115 (Label: real)
#
# --- Tournament Finished ---
#
# --- Top 100 Selected Abstracts (Label, Text, Wins) ---
# 1. Index: 3, Original Label: gen, Wins: 5, Text: Obesity is a complex metabolic disorder that is associated with the development of several chronic d...
# 2. Index: 15, Original Label: real, Wins: 5, Text: Pancreatic cancer is a highly lethal malignancy with limited treatment response. Despite advancement...
